# %%
import numpy as np
import matplotlib.pyplot as plt
import pydicom

# %%
sample_dcm = 'C:/E0323036-SEM6/dl_med/N2D_0109.dcm'
dicom_file = pydicom.dcmread(sample_dcm)
print(dicom_file)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 236
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.2.1143.6322065350367499070836115239556784492
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.2.8.3
# (0002,0013) Implementation Version Name         SH: 'GDCM 2.8.3'
# (0002,0016) Source Application Entity Title     AE: 'gdcmanon'
# -------------------------------------------------
# (0008,0008) Image Type                          CS: ['DERIVED', 'SECONDARY']
# (0008,0016) SOP Class UID                       UI: MR Image Storage
# ...

# %%
print(dicom_file[0x0028, 0x0010])
print(dicom_file[0x0028, 0x0011])
# Out:
# (0028,0010) Rows                                US: 384
# (0028,0011) Columns                             US: 274

# %%
value = dicom_file.get((0x0018, 0x0022), "Tag not found")
print(value)
print('Rows: ', dicom_file.Rows)
print('Columns: ', dicom_file.Columns)
print(dicom_file[0x0008, 0x103E])
# Out:
# Tag not found
# Rows:  384
# Columns:  274
# (0008,103E) Series Description                  LO: 'anat-T1w'

# %%
ct = dicom_file.pixel_array 
plt.figure()
plt.imshow(ct, cmap="gray")
print(ct.shape)
# Out:
# (384, 274)
